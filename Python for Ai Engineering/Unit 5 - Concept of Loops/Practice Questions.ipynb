# %%
#Print the missing value [1,2,3,5]. the numbers is from 1 to 5

num = [1,2,3,5]
expected_sum = sum(range(1,6))
actual_sum = sum(num)
missing = expected_sum - actual_sum
print(missing)
# Out:
# 4
