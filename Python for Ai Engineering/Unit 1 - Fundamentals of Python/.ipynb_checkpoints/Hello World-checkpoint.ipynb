# %% [markdown]
# # Python Fundamentals

# %% [markdown]
# import sys
# sys.version

# %% [markdown]
# # python comments

# %%
# This is the comment and will not be shown in output
print ("comments")
# Out:
# comments

# %% [markdown]
# # multiline comment

# %%
"""
steps of program
1. take number
2. square the number
3. print the result
"""

num = 5
square = num*num
print(square)
# Out:
# 25
