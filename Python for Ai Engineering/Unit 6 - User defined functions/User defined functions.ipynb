# %% [markdown]
# # User defined functions
#
# Functions we defined ourselves to perform specific task.
#
# # Advantages of user-defined functions
# - User-defined functions help to decompose a large program into small segments which makes program easy to understand, maintain and debug.
# - If repeated code occurs in a program. Function can be used to include those codes and execute when needed by calling that function.
# - Programmars working on large project can divide the workload by making different functions.

# %% [markdown]
# # Creating a function

# %%
# Function is defined using the def keyword

def abc():
    print("Hello Bilal")
abc()
# Out:
# Hello Bilal

# %% [markdown]
# def details():
#     print("The last date of paying Bill is 10 July 2026")
#     print("After deadline you have to pay extra 100 Rupees")
#     print("Pay your bill on time")

# %%
for i in range(3):
    a = input("Enter your name")
    n = int(input("Enter units comsumes"))
    bill = n*10
    print("You need to pay:", bill)
    details()
# Out:
# Enter your name Bilal
# Enter units comsumes 100
# You need to pay: 1000
# The last date of paying Bill is 10 July 2026
# After deadline you have to pay extra 100 Rupees
# Pay your bill on time
# Enter your name Asad
# Enter units comsumes 200
# You need to pay: 2000
# The last date of paying Bill is 10 July 2026
# After deadline you have to pay extra 100 Rupees
# Pay your bill on time
# Enter your name Umar
# Enter units comsumes 300
# You need to pay: 3000
# The last date of paying Bill is 10 July 2026
# After deadline you have to pay extra 100 Rupees
# Pay your bill on time

# %% [markdown]
# # Function Arguments

# %%
def demo(fname):
    print(fname + " Ramzan")
demo("Bilal")
# Out:
# Bilal Ramzan19

# %%
demo("Afzal",19)
# Out:
# Afzal Ramzan

# %%
demo("sadia",28)
# Out:
# sadia Ramzan

# %% [markdown]
# # Two arguments

# %%
def demo(fname, mname):
    print(fname + " " + mname + " " + "Ramzan")
demo("Bilal", "Ali")
# Out:
# Bilal Ali Ramzan
