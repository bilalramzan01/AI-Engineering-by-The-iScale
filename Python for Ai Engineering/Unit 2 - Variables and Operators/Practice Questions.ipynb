# %%
# Find the area of the rectangle with length 12cm and width 6 cm.
length = 12
width = 6
area = length*width
print("The area of the Rectangle is: ",area)
# Out:
# The area of the Rectangle is:  72
