# %% [markdown]
# ## PANDAS
# Pandas is an open-source Python library used for data manipulation, analysis and cleaning. It provides fast and flexible tools to work with tabular data, similar to spreadsheets or SQL tables.
# A fast and efficient DataFrame object for data manipulation with integrated indexing;
#
# Tools for reading and writing data between in-memory data structures and different formats: CSV and text files, Microsoft Excel, SQL databases, and the fast HDF5 format;
#
# Intelligent data alignment and integrated handling of missing data: gain automatic label-based alignment in computations and easily manipulate messy data into an orderly form;
#
# Flexible reshaping and pivoting of data sets;
#
# Intelligent label-based slicing, fancy indexing, and subsetting of large data sets;
#
# Columns can be inserted and deleted from data structures for size mutability;
#
# Aggregating or transforming data with a powerful group by engine allowing split-apply-combine operations on data sets;
#
# High performance merging and joining of data sets;
#
# Hierarchical axis indexing provides an intuitive way of working with high-dimensional data in a lower-dimensional data structure;

# %%
import pandas as pd

# %%
# Titanic Data set

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# To perform basic analysis

df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# To take data of your own choice

df[['Name','Sex','Ticket','Fare','Sex','Age']]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket     Fare     Sex   Age
# 0           A/5 21171   7.2500    male  22.0
# 1            PC 17599  71.2833  female  38.0
# 2    STON/O2. 3101282   7.9250  female  26.0
# ...

# %%
# To figure out how many rows or colomns have float data type(or anyother)

df[df.dtypes[df.dtypes=='float'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df[df.dtypes[df.dtypes=='int'].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# To slice any column or row of your own choice
df[['Ticket']][5:15]
# Out:
#        Ticket
# 5      330877
# 6       17463
# 7      349909
# 8      347742
# 9      237736
# 10    PP 9549
# 11     113783
# 12  A/5. 2151
# 13     347082
# 14     350406

# %%
# Need jump or alternate
df[['Ticket']][5:15:3]
# Out:
#     Ticket
# 5   330877
# 8   347742
# 11  113783
# 14  350406

# %%
# Slice with more then 2 columns
df[['Ticket', 'Age']][5:15:3]
# Out:
#     Ticket   Age
# 5   330877   NaN
# 8   347742  27.0
# 11  113783  58.0
# 14  350406  14.0

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Add custom column at the end

df['Bilal'] = 3
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Bilal
# 0      0         A/5 21171   7.2500   NaN        S      3
# 1      0          PC 17599  71.2833   C85        C      3
# 2      0  STON/O2. 3101282   7.9250   NaN        S      3
# 3      0            113803  53.1000  C123        S      3
# ...

# %%
# Add custom column at any place

df.insert( loc=3 , column = 'wood', value =5)
df.head()
# Out:
#    PassengerId  Survived  Pclass  wood  \
# 0            1         0       3     5
# 1            2         1       1     5
# 2            3         1       3     5
# 3            4         1       1     5
# 4            5         0       3     5
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Bilal
# 0      0         A/5 21171   7.2500   NaN        S      3
# 1      0          PC 17599  71.2833   C85        C      3
# 2      0  STON/O2. 3101282   7.9250   NaN        S      3
# ...

# %%
df.insert(loc = 8, column = 'Equipment', value = "football")
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  wood  \
# 0            1         0       3     5
# 1            2         1       1     5
# 2            3         1       3     5
# 3            4         1       1     5
# 4            5         0       3     5
# 5            6         0       3     5
# 6            7         0       1     5
# 7            8         0       3     5
# 8            9         1       3     5
# 9           10         1       2     5
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
new_row = {
    'Survived' : 1,
    'Sex': 'Male'
    }

print(new_row)
# Out:
# {'Survived': 1, 'Sex': 'Male'}

# %%
# Add row or dict in data frame at the end

df = pd.concat([df, pd.DataFrame([new_row])], ignore_index = True)

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass  wood  \
# 887        888.0         1     1.0   5.0
# 888        889.0         0     3.0   5.0
# 889        890.0         1     1.0   5.0
# 890        891.0         0     3.0   5.0
# 891          NaN         1     NaN   NaN
#
#                                          Name     Sex   Age  SibSp Equipment  \
# 887              Graham, Miss. Margaret Edith  female  19.0    0.0  football
# 888  Johnston, Miss. Catherine Helen "Carrie"  female   NaN    1.0  football
# 889                     Behr, Mr. Karl Howell    male  26.0    0.0  football
# 890                       Dooley, Mr. Patrick    male  32.0    0.0  football
# 891                                       NaN    Male   NaN    NaN       NaN
#
#      Parch      Ticket   Fare Cabin Embarked  Bilal
# 887    0.0      112053  30.00   B42        S    3.0
# 888    2.0  W./C. 6607  23.45   NaN        S    3.0
# 889    0.0      111369  30.00  C148        C    3.0
# ...
