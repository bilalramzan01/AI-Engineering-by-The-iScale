# %% [markdown]
# # List
# - Container used to store a different type of data in a single variable.
# - it used square brackets [] and separated by comas.
# - It allows duplicate values

# %%
fruits = ["Apple","Banana","Cherry", "Grapes"]
print(fruits)
print(type(fruits))
# Out:
# ['Apple', 'Banana', 'Cherry', 'Grapes']
# <class 'list'>

# %%
a = [12,23.45,"Cherry", "Grapes"]
print(a)
print(type(a))
# Out:
# [12, 23.45, 'Cherry', 'Grapes']
# <class 'list'>

# %%
a = [12,23.45,"Cherry", "Grapes",12,12, True, False]
print(a)
print(type(a))
# Out:
# [12, 23.45, 'Cherry', 'Grapes', 12, 12, True, False]
# <class 'list'>
