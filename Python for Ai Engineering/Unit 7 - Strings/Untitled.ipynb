# %% [markdown]
# # Strings
# - Sequence of characaters enclosed in single or double quotes.
# - We can use triple single or double quotes for multi-line strings.
#
# # Indexing of Strings
# Indexing in strings refers to accessing individual characters in a string using their position (index). Python uses zero-based indexing, meaning the first character of a string has an index of 0, the second character has an index of 1, and so on. Negative indexing can also be used to access characters from the end of the string, where -1 is the last character, -2 is the second last, and so forth.
#
# # Slicing of Strings
# Slicing in Python allows you to extract a part of a string (substring) using a range of indices. This is done using the slicing operator, which is a colon : inside square brackets [ ].

# %%
a = "Hello"
print(a)
print(type(a))
# Out:
# Hello
# <class 'str'>

# %%
b = ''' Hello Bilal
        How are you?
        are you good today'''
print(b)
# Out:
#  Hello Bilal
#         How are you?
#         are you good today

# %%
a = "Hello Students"
print(a[0:4])
print(a[-4:])
# Out:
# Hell
# ents

# %%
a = "How are you"
print(a[4:7])
# Out:
# are

# %%
# how  much characters skip
a = "How are you"
print(a[::2])
# Out:
# Hwaeyu

# %% [markdown]
# # Reverse String

# %%
a = "Hello"
b = a[::-1]
print(a)
print(b)
# Out:
# Hello
# olleH

# %%
a = "racecar"
if a==a[::-1]:
    print("word is palindrome")
else:
    print("Word is not palindrome")
# Out:
# word is palindrome

# %% [markdown]
# # Length

# %%
a = "Hellllooo"
print(len(b))
# Out:
# 5

# %% [markdown]
# # Check Character

# %%
a = "Lahore is in Pakistan"
print("Pakistan" in a)
# Out:
# True

# %% [markdown]
# # Upper and Lower method

# %%
a = "bilal"
b = "Bilal"
print(a.upper())
print(b.lower())
# Out:
# BILAL
# bilal

# %% [markdown]
# # Replace method

# %%
a = "Hello Wajeh"
print(a.replace("Wajeh","Bilal"))
# Out:
# Hello Bilal

# %% [markdown]
# # String Concatenation

# %%
a = "Hello"
b = "World"
print(a+b)
# Out:
# HelloWorld

# %%
a = '''When Guido van Rossum was designing Python, languages like C, C++, and Java were already dominant standard-bearers, 
all using zero-based indexing. By adopting 0 as the starting index, Python ensured that programmers transitioning from other
languages wouldn't constantly suffer from "off-by-one" errors out of habit.'''

print(a.find("g"))
# Out:
# 30
