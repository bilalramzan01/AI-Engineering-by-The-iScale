# %% [markdown]
# # Practice Questions

# %% [markdown]
# # Question 1
# Create variables to store:
# Your name
# Your age
# Your favorite programming language
# Print them in a single sentence.

# %%
name = "Bilal"
age = 22
fav_lang = "Python"
print(name,age,fav_lang)
# Out:
# Bilal 22 Python

# %% [markdown]
# # Question 2
# Store the length and width of a rectangle in variables and calculate its area.

# %%
length = 12
width = 10
area = length*width
print(area)
# Out:
# 120

# %% [markdown]
# # Question 3
# Store the values of two variables and swap them without using a third variable.

# %%
a = 15
b = 10
a = a+b
b = a-b
a = a-b
print("a is:", a)
print("b is:", b)
# Out:
# a is: 10
# b is: 15

# %% [markdown]
# # Question 3
# temperature = 38,
# Convert it from Celsius to Fahrenheit.

# %%
temperature = 38
F = (temperature * 9/5) + 32
print(F)
# Out:
# 100.4

# %% [markdown]
# # Question 4
# Take three variables and print the largest value.

# %%
a = int(input("Enter the value of a:"))
b = int(input("Enter the value of b:"))
c = int(input("Enter the value of c:"))

if a >= b and a >= c:
    print("a is the largest:", a)
elif b >= a and b >= c:
    print("b is the largest:", b)
else:
    print("c is the largest:", c)
# Out:
# Enter the value of a: 23
# Enter the value of b: 43
# Enter the value of c: 55
# c is the largest: 55

# %% [markdown]
# # Question 5
# Take two numbers and print:
# - Sum
# - Difference
# - Product
# - Division

# %%
a = 30
b = 20
sum = a+b
sub = a-b
pro = a*b
div = a/b
print(sum,sub,pro,div)
# Out:
# 50 10 600 1.5

# %% [markdown]
# # Question 6
# Find the remainder when 57 is divided by 8.

# %%
rem = 57%8
print(rem)
# Out:
# 1

# %% [markdown]
# # Question 7
# Check if two numbers are equal.

# %%
a = 10
b = 11
if a==b:
    print ("numbers are equal")
else:
    print("not equal")
# Out:
# not equal

# %% [markdown]
# # Question 8
# Check whether a person is eligible to vote (age ≥ 18).

# %%
a = int(input("enter your age"))

if a>=18:
    print("eligiable for vote")
else:
    print("not eligible")
# Out:
# enter your age 12
# not eligible

# %% [markdown]
# # Question 9
# Determine whether a number is even without using %.

# %%
a = int(input("enter your number"))
if a/2==int(a/2):
    print("Even number")
else:
    print("Not even")
# Out:
# enter your number 0
# Even number

# %%
With using the modulus
a = int(input("enter your number"))
if a%2==0:
    print("Even number")
else:
    print("Not even")
# Out:
# enter your number 1
# Not even

# %% [markdown]
# # Question 10
# Check if a number is positive, negative, or zero.

# %%
a = float(input("Enter the num:"))
if a==0:
    print("Num is zero")
elif a>0:
    print("positive num")
else:
    print("Negative num")
# Out:
# Enter the num: -.05
# Negative num

# %% [markdown]
# # Question 11
# Find the largest of two numbers.

# %%
a = float(input("enter num"))
b = float(input("enter num"))
if a>b:
    print( "a is largest")
elif b > a:
    print("b is largest")
else:
    print("Both numbers are equal")
# Out:
# enter num 12
# enter num 12
# Both numbers are equal

# %% [markdown]
# # Question 12
# Find the largest of three numbers.

# %%
a = float(input("enter num a:"))
b = float(input("enter num b:"))
c = float(input("enter num c:"))
largest = max(a,b,c)
print("largest num is:", largest)
# Out:
# enter num a: 45
# enter num b: 54
# enter num c: 23
# largest num is: 54.0

# %% [markdown]
# # Question 13
# Check whether a year is a leap year.

# %%
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Enter a year:  2024
# Leap year

# %% [markdown]
# # Question 14
# Input marks and print:
#
# A (90–100)
# B (80–89)
# C (70–79)
# D (60–69)
# F (<60)

# %%
marks = int(input("Enter your marks: "))

if marks>=90 and marks<=100:
    print("A Grade")
elif marks>=80 and marks<=89:
    print("B Grade")
elif marks>=70 and marks<=79:
    print("C Grade")
elif marks>=60 and marks<=69:
    print("D Grade")
elif marks<60:
    print("F Grade")
else:
    print("not in range")
# Out:
# Enter a year:  123
# NOT IN LIST

# %% [markdown]
# # Question 15
# Check whether a number is divisible by both 3 and 5.

# %%
num = int(input("Enter the number"))
if num%3==0 and num%5==0:
    print("Divisble by both")
else:
    print("Not divisble by both")
# Out:
# Enter the number 12
# Not divisble by both

# %%
num = int(input("Enter the number: "))

# Checking if it's divisible by 15 does the exact same job!
if num % 15 == 0:
    print("Divisible by both")
else:
    print("Not divisible by both")
# Out:
# Enter the number:  45
# Divisible by both

# %% [markdown]
# # Question 16
# Check if a character is a vowel or consonant.

# %%
a = input("Enter the character: ")
a = a.lower()

# A one-line decision
result = "Vowel" if a in "aeiou" else "Consonant"

print("It is a", result)
# Out:
# Enter the character:  s
# It is a Consonant
